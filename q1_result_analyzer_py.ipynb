# %%
def analyze_result(name, roll, marks):
  total = sum(marks)
  average = total / len(marks)

  if average >= 90:
    grade = "A"
  elif average >= 75:
    grade = "B"
  elif average >= 60:
    grade = "C"
  elif average >= 40:
    grade = "D"
  else:
    grade = "Fail"

  print(f"student:{name} (Roll:{roll})")
  print(f"Total:{total} Average:{average}")
  print(f"Grade:{grade}")

  for i in range(len(marks)):
    if marks[i] < 40:
      print(f"Subject below 40:Subject {i+1}")

analyze_result("Aarav",101,[88.5, 35.0, 76.0, 92.5, 48.0])
# Out:
# student:Aarav (Roll:101)
# Total:340.0 Average:68.0
# Grade:C
# Subject below 40:Subject 2
